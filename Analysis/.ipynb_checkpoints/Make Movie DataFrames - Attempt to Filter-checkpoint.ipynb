# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pickle
with open('../data/movie_response_dict.pickle') as p:
    movie_dict = pickle.load(p)

# %%
len(movie_dict)
# Out:
# 26901

# %%
movie_dict.keys()[0]
# Out:
# 2

# %%
movie_dict[2]
# Out:
# {u'adult': False,
#  u'backdrop_path': u'/z2QUexmccqrvw1kDMw3R8TxAh5E.jpg',
#  u'belongs_to_collection': {u'backdrop_path': u'/ibLeWo3X3dVo4rxvn4m3y90ms1I.jpg',
#   u'id': 8384,
#   u'name': u'Proletariat Collection',
#   u'poster_path': None},
#  u'budget': 0,
#  u'genres': [{u'id': 18, u'name': u'Drama'},
#   {u'id': 10769, u'name': u'Foreign'}],
#  u'homepage': u'',
#  u'id': 2,
#  u'imdb_id': u'tt0094675',
#  u'original_language': u'fi',
#  u'original_title': u'Ariel',
#  u'overview': u"Taisto Kasurinen is a Finnish coal miner whose father has just committed suicide and who is framed for a crime he did not commit. In jail, he starts to dream about leaving the country and starting a new life. He escapes from prison but things don't go as planned...",
#  u'popularity': 0.557001,
#  u'poster_path': u'/w0NzAc4Lv6euPtPAmsdEf0ZCF8C.jpg',
#  u'production_companies': [{u'id': 2303,
#    u'name': u'Villealfa Filmproduction Oy'},
#   {u'id': 2396, u'name': u'Finnish Film Foundation'}],
# ...

# %%
[u'id',u'imdb_id',u'title',u'revenue',u'overview',
 u'popularity', u'runtime', u'release_date',u'tagline',
 u'vote_count',u'vote_average', u'genres',u'video',
 

 
 
 
 u'homepage',
 u'belongs_to_collection',
 u'original_language',
 u'status',
 u'spoken_languages',
 
 u'adult',
 u'backdrop_path',
 u'production_companies',
 u'release_date',
 
 u'original_title',
 u'budget',
 
]

# %%
from pandas.io.json import json_normalize

# %%
movie_df = json_normalize(movie_dict.values())

# %%
movie_df.shape
# Out:
# (26901, 29)

# %%
for c in movie_df.columns:
    print c
# Out:
# adult
# backdrop_path
# belongs_to_collection
# belongs_to_collection.backdrop_path
# belongs_to_collection.id
# belongs_to_collection.name
# belongs_to_collection.poster_path
# budget
# genres
# homepage
# id
# imdb_id
# original_language
# original_title
# overview
# popularity
# poster_path
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# video
# vote_average
# vote_count

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26901 entries, 0 to 26900
# Data columns (total 29 columns):
# adult                                  26901 non-null bool
# backdrop_path                          22759 non-null object
# belongs_to_collection                  0 non-null float64
# belongs_to_collection.backdrop_path    1918 non-null object
# belongs_to_collection.id               2960 non-null float64
# belongs_to_collection.name             2960 non-null object
# belongs_to_collection.poster_path      2580 non-null object
# budget                                 26901 non-null int64
# genres                                 26901 non-null object
# homepage                               26679 non-null object
# id                                     26901 non-null int64
# imdb_id                                26901 non-null object
# original_language                      26901 non-null object
# original_title                         26901 non-null object
# ...

# %%
pd.to_datetime(movie_df.release_date).describe()
# Out:
# count                   26830
# unique                  12669
# top       2008-01-01 00:00:00
# freq                       87
# first     1891-01-01 00:00:00
# last      2015-12-11 00:00:00
# Name: release_date, dtype: object

# %%
movie_df.popularity.describe()
# Out:
# count    26901.000000
# mean         0.349069
# std          0.749818
# min          0.000000
# 25%          0.000329
# 50%          0.015000
# 75%          0.439143
# max         22.109250
# Name: popularity, dtype: float64

# %%
plt.hist(np.log(movie_df.popularity+1),bins=100)
plt.show()

# %%
movie_df[movie_df.popularity>0.1].popularity.describe()
# Out:
# count    11336.000000
# mean         0.816982
# std          0.977387
# min          0.100006
# 25%          0.283457
# 50%          0.554002
# 75%          1.041519
# max         22.109250
# Name: popularity, dtype: float64

# %%
movie_df[movie_df.popularity>10]
# Out:
#        adult                     backdrop_path  belongs_to_collection  \
# 285    False   /L5QRL1O3fGs2hH1LbtYyVl8Tce.jpg                    NaN
# 403    False  /wUdsw5jvnsGRsuA9e4MMSP3TD2B.jpg                    NaN
# 8664   False  /xjjO3JIdneMBTsS282JffiPqfHW.jpg                    NaN
# 9076   False  /fUn5I5f4069vwGFEEvA3HXt9xPP.jpg                    NaN
# 10739  False  /xu9zaAevzQ5nnrsXN6JcahLnG4i.jpg                    NaN
# 19743  False  /9eb23pW5JdAfgK6vp4XzUwmNtR0.jpg                    NaN
# 20799  False  /y5lG7TBpeOMG0jxAaTK0ghZSzBJ.jpg                    NaN
# 20854  False   /yTbPPmLAn7DiiM0sPYfZduoAjB.jpg                    NaN
# 21738  False  /fii9tPZTpy75qOCJBulWOb0ifGp.jpg                    NaN
# 22006  False  /9eKd1DDDAbrDNXR2he7ZJEu7UkI.jpg                    NaN
# 22026  False  /4liSXBZZdURI0c1Id1zLJo6Z3Gu.jpg                    NaN
# 23714  False  /2BXd0t9JdVqCp9sKf6kzMkr7QjB.jpg                    NaN
# ...
